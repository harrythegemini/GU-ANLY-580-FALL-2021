# %% [markdown]
# # Lab 01: Setup computing environment

# %% [markdown]
# ### Task 1: Run this block of code to ensure that your dependencies are installed

# %%
import numpy as np
import tensorflow
import torch

# %% [markdown]
# ### Task 2: Complete the function `linear_transformation()` by implementing a matrix multiplication between the data matrix, `X` of size `M x N`, and the tensor, `W` of size `N x N` (an identity matrix).

# %%
def linear_transformation(X, W):
    """
    Parameters
    ----------
    X: np.array (M x N)
        Data matrix
    W: np.array(N x N)
        Linear transformation
    Returns
    -------
    X_prime: np.array (M x N)
    """
    # Your code goes here
    pass

# %%
W = np.identity(10)
X = np.random.random((300, 10))

# %%
X_tx = linear_transformation(X, W)
assert (X_tx == X).all()
